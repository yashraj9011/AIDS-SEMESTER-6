# %% [markdown]
# # 31 Yashraj Deepak Devrat
#
# Text Analytics
# 1. Extract Sample document and apply following document preprocessing methods:
# Tokenization, POS Tagging, stop words removal, Stemming and Lemmatization.
# 2. Create representation of documents by calculating Term Frequency and Inverse
# DocumentFrequency.

# %%
# Import Libraries 
# Tokenization
import seaborn as sns
from matplotlib import pyplot as plt
import nltk
import numpy as np
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()
from nltk import pos_tag
to_be_removed = set(stopwords.words('english'))
#from WordCloud import worldcloud
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(stop_words='english')

# %%
'''
1 Tokenization

word_tokenize
sent_tokenize

2 Remove Noise

Punctution
stop words

3 Stemming Snowball stemmer  | porters stemmer

4 lemmatization

5 POS Tagging

6 Wordcloud

7 freqdist





'''
# Out:
# '\n1 Tokenization\n\nword_tokenize\nsent_tokenize\n\n2 Remove Noise\n\nPunctution\nstop words\n\n3 Stemming Snowball stemmer  | porters stemmer\n\n4 lemmatization\n\n5 POS Tagging\n\n6 Wordcloud\n\n7 freqdist\n\n\n\n\n\n'

# %%
txt="""Cake is a form of sweet food made from flour, sugar, and other ingredients, that is usually baked.
In their oldest forms, cakes were modifications of bread, but cakes now cover a wide range of preparations 
that can be simple or elaborate, and that share features with other desserts such as pastries, meringues, custards, 
and pies."""

# %% [markdown]
# # Tokenization
# Tokenization is the process of breaking down the given text in natural language processing into the smallest unit in a sentence called a token. Punctuation marks, words, and numbers can be considered tokens.

# %%
tokenized_text=word_tokenize(txt)
print(tokenized_text)
print(type(tokenized_text))
# Out:
# ['Cake', 'is', 'a', 'form', 'of', 'sweet', 'food', 'made', 'from', 'flour', ',', 'sugar', ',', 'and', 'other', 'ingredients', ',', 'that', 'is', 'usually', 'baked', '.', 'In', 'their', 'oldest', 'forms', ',', 'cakes', 'were', 'modifications', 'of', 'bread', ',', 'but', 'cakes', 'now', 'cover', 'a', 'wide', 'range', 'of', 'preparations', 'that', 'can', 'be', 'simple', 'or', 'elaborate', ',', 'and', 'that', 'share', 'features', 'with', 'other', 'desserts', 'such', 'as', 'pastries', ',', 'meringues', ',', 'custards', ',', 'and', 'pies', '.']
# <class 'list'>

# %%
# split the text into sentences
sent_tokens = sent_tokenize(txt)
sent_tokens
# Out:
# ['Cake is a form of sweet food made from flour, sugar, and other ingredients, that is usually baked.',
#  'In their oldest forms, cakes were modifications of bread, but cakes now cover a wide range of preparations \nthat can be simple or elaborate, and that share features with other desserts such as pastries, meringues, custards, \nand pies.']

# %%
# split the text into words
word_tokens = word_tokenize(txt)
word_tokens
# Out:
# ['Cake',
#  'is',
#  'a',
#  'form',
#  'of',
#  'sweet',
#  'food',
#  'made',
#  'from',
#  'flour',
#  ',',
#  'sugar',
#  ',',
#  'and',
#  'other',
#  'ingredients',
#  ',',
#  'that',
#  'is',
#  'usually',
#  'baked',
#  '.',
#  'In',
#  'their',
#  'oldest',
#  'forms',
#  ',',
#  'cakes',
#  'were',
#  'modifications',
#  'of',
#  'bread',
#  ',',
#  'but',
#  'cakes',
#  'now',
#  'cover',
#  'a',
#  'wide',
#  'range',
#  'of',
#  'preparations',
#  'that',
#  'can',
#  'be',
#  'simple',
#  'or',
#  'elaborate',
#  ',',
#  'and',
#  'that',
#  'share',
#  'features',
#  'with',
#  'other',
#  'desserts',
#  'such',
#  'as',
#  'pastries',
#  ',',
#  'meringues',
#  ',',
#  'custards',
#  ',',
#  'and',
#  'pies',
#  '.']

# %%
modified_token_list=[word for word in tokenized_text if not word in to_be_removed]
print(modified_token_list)
# Out:
# ['Cake', 'form', 'sweet', 'food', 'made', 'flour', ',', 'sugar', ',', 'ingredients', ',', 'usually', 'baked', '.', 'In', 'oldest', 'forms', ',', 'cakes', 'modifications', 'bread', ',', 'cakes', 'cover', 'wide', 'range', 'preparations', 'simple', 'elaborate', ',', 'share', 'features', 'desserts', 'pastries', ',', 'meringues', ',', 'custards', ',', 'pies', '.']

# %% [markdown]
# # Text Without Punctuation Marks

# %%
import re


txt = re.sub(r'[^\w\s]', '', txt)

# printing result
print( txt)
# Out:
# Cake is a form of sweet food made from flour sugar and other ingredients that is usually baked
# In their oldest forms cakes were modifications of bread but cakes now cover a wide range of preparations
# that can be simple or elaborate and that share features with other desserts such as pastries meringues custards
# and pies

# %% [markdown]
# # Stemming
# Stemming is the process of finding the root of words. A word stem need not be the same root as a dictionary-based morphological root, it just is an equal to or smaller form of the word.

# %%
ps = PorterStemmer()

# %%
word = ('cakes')
ps.stem(word)
# Out:
# 'cake'

# %%
stemmed_sentence = " ".join(ps.stem(word) for word in word_tokens)
stemmed_sentence
# Out:
# 'cake is a form of sweet food made from flour , sugar , and other ingredi , that is usual bake . in their oldest form , cake were modif of bread , but cake now cover a wide rang of prepar that can be simpl or elabor , and that share featur with other dessert such as pastri , meringu , custard , and pie .'

# %%
tk_txt=word_tokenize(txt)
stemmed_words = [stemmer.stem(i) for i in tk_txt] 
print(stemmed_words)
# Out:
# ['cake', 'is', 'a', 'form', 'of', 'sweet', 'food', 'made', 'from', 'flour', 'sugar', 'and', 'other', 'ingredi', 'that', 'is', 'usual', 'bake', 'in', 'their', 'oldest', 'form', 'cake', 'were', 'modif', 'of', 'bread', 'but', 'cake', 'now', 'cover', 'a', 'wide', 'rang', 'of', 'prepar', 'that', 'can', 'be', 'simpl', 'or', 'elabor', 'and', 'that', 'share', 'featur', 'with', 'other', 'dessert', 'such', 'as', 'pastri', 'meringu', 'custard', 'and', 'pie']

# %% [markdown]
# # Lemmatization
# Lemmatization is the process of finding the form of the related word in the dictionary. It is different from Stemming. It involves longer processes to calculate than Stemming.

# %%
lemmatizer.lemmatize('stem')
# Out:
# 'stem'

# %%
word_tokens = word_tokenize(txt)

# %%
lemmatized_sentence = " ".join(lemmatizer.lemmatize(word.lower()) for word in word_tokens)
lemmatized_sentence
# Out:
# 'cake is a form of sweet food made from flour sugar and other ingredient that is usually baked in their oldest form cake were modification of bread but cake now cover a wide range of preparation that can be simple or elaborate and that share feature with other dessert such a pastry meringue custard and pie'

# %%
lemmatized_words = [lemmatizer.lemmatize(i) for i in tk_txt] 
print(lemmatized_words)
# Out:
# ['Cake', 'is', 'a', 'form', 'of', 'sweet', 'food', 'made', 'from', 'flour', 'sugar', 'and', 'other', 'ingredient', 'that', 'is', 'usually', 'baked', 'In', 'their', 'oldest', 'form', 'cake', 'were', 'modification', 'of', 'bread', 'but', 'cake', 'now', 'cover', 'a', 'wide', 'range', 'of', 'preparation', 'that', 'can', 'be', 'simple', 'or', 'elaborate', 'and', 'that', 'share', 'feature', 'with', 'other', 'dessert', 'such', 'a', 'pastry', 'meringue', 'custard', 'and', 'pie']

# %% [markdown]
# # POS Tagging
# Part of Speech Tagging is a process of converting a sentence to forms — list of words, list of tuples (where each tuple is having a form (word, tag)). The tag in case of is a part-of-speech tag, and signifies whether the word is a noun, adjective, verb, and so on.

# %%
pos_tag(['hi'])
# Out:
# [('hi', 'NN')]

# %%
word_tokens = word_tokenize(txt)

# %%
pos_tag(word_tokens)
# Out:
# [('Cake', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('form', 'NN'),
#  ('of', 'IN'),
#  ('sweet', 'JJ'),
#  ('food', 'NN'),
#  ('made', 'VBN'),
#  ('from', 'IN'),
#  ('flour', 'JJ'),
#  ('sugar', 'NN'),
#  ('and', 'CC'),
#  ('other', 'JJ'),
#  ('ingredients', 'NNS'),
#  ('that', 'WDT'),
#  ('is', 'VBZ'),
#  ('usually', 'RB'),
#  ('baked', 'VBN'),
#  ('In', 'IN'),
#  ('their', 'PRP$'),
#  ('oldest', 'JJS'),
#  ('forms', 'NNS'),
#  ('cakes', 'NNS'),
#  ('were', 'VBD'),
#  ('modifications', 'NNS'),
#  ('of', 'IN'),
#  ('bread', 'NN'),
#  ('but', 'CC'),
#  ('cakes', 'NNS'),
#  ('now', 'RB'),
#  ('cover', 'VBP'),
#  ('a', 'DT'),
#  ('wide', 'JJ'),
#  ('range', 'NN'),
#  ('of', 'IN'),
#  ('preparations', 'NNS'),
#  ('that', 'WDT'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('simple', 'JJ'),
#  ('or', 'CC'),
#  ('elaborate', 'JJ'),
#  ('and', 'CC'),
#  ('that', 'DT'),
#  ('share', 'NN'),
#  ('features', 'VBZ'),
#  ('with', 'IN'),
#  ('other', 'JJ'),
#  ('desserts', 'NNS'),
# ...

# %% [markdown]
# # WordCloud

# %%
plt.figure(figsize=(10,10),facecolor='none')
wordcloud=WordCloud().generate(txt)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# # Term Frequency
# TF-IDF (Term Frequency/Inverse Document Frequency) TF-IDF stands for term frequency-inverse document frequency and it is a measure, used in the fields of information retrieval (IR) and machine learning, that can quantify the importance or relevance of string representations (words, phrases, lemmas, etc) in a document amongst a collection of documents

# %%
plt.figure(figsize=(11,8))
words = nltk.tokenize.word_tokenize(txt)
fd = nltk.FreqDist(words)
fd.plot()
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>
