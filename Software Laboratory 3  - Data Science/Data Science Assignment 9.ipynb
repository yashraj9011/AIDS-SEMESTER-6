# %% [markdown]
# # Data Visualization II
# 1. Use the inbuilt dataset 'titanic' as used in the above problem. Plot a box plot for distribution of
# age with respect to each gender along with the information about whether they survived or
# not. (Column names : 'sex' and 'age')
# 2. Write observations on the inference from the above statistics.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # Boxplot
# The box represents the interquartile range (IQR), which is the middle 50% of the data, and the line inside the box represents the median age. The whiskers extend to the most extreme data points within 1.5 times the IQR, and any points beyond the whiskers are considered outliers.

# %%
sns.boxplot(x='sex', y='age', hue='survived', data=titanic)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
x = 'fare'
plt.hist(x, bins=5)
plt.show()

# %%
sns.distplot(titanic['fare'])
# Out:
# /tmp/ipykernel_8326/1210902909.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['fare'])
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %%
sns.violinplot(x='sex', y='age', data=titanic)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.histplot(titanic['fare'])
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
sns.jointplot(y='fare',x='sex',data=titanic)

# %%
sns.swarmplot(x='sex',y='age',data=titanic,palette='Set2')
# Out:
# /tmp/ipykernel_8326/1542787325.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x='sex',y='age',data=titanic,palette='Set2')
# <AxesSubplot:xlabel='sex', ylabel='age'>
# /home/yashraj/.local/lib/python3.10/site-packages/seaborn/categorical.py:3544: UserWarning: 7.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.countplot(x='sex',data=titanic)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.heatmap(titanic.corr(),cmap='Blues')
plt.title('titanic.corr()')
# Out:
# /tmp/ipykernel_8326/1589527752.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(),cmap='Blues')
# Text(0.5, 1.0, 'titanic.corr()')

# %%
sns.distplot(titanic['fare'], kde=False)
# Out:
# /tmp/ipykernel_8326/3298025273.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['fare'], kde=False)
# <AxesSubplot:xlabel='fare'>

# %%
sns.jointplot(x='age',y='fare',data=titanic,kind='hex')

# %%
#pairplot
sns.pairplot(titanic)
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
sns.pairplot(titanic, hue= 'sex' )

# %%
sns.rugplot(titanic['fare'])

# %%
sns.barplot(x= 'sex' , y= 'age' , data=titanic, estimator=np.std)
# Out:
# /usr/lib/python3/dist-packages/numpy/lib/nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# /usr/lib/python3/dist-packages/numpy/lib/nanfunctions.py:1374: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.boxplot(x= 'sex' , y= 'age' , data=titanic, hue= "survived" )
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.stripplot(x= 'sex' , y= 'age' , data=titanic)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.stripplot(x='sex',y='age',data=titanic, jitter=True, hue='survived')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %% [markdown]
# # Observations
#
# 1. The median age of both male and female passengers who survived is higher than the median age of those who did not survive.
#
#  2.The age range of male passengers who did not survive is wider than the age range of male passengers who survived.
#
#
#   3. The age range of female passengers who survived is wider than the age range of female passengers who did not survive.
#
#   4. It seems that age was a factor in determining whether a passenger survived or not, with younger passengers having a higher chance of survival. However, this trend is more pronounced among male passengers, as the age range of male passengers who did not survive is wider than the age range of male passengers who survived. Among female passengers, age seems to have less of an impact on survival, as the age range of female passengers who survived is wider than the age range of female passengers who did not survive.
